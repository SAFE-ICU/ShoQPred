# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pickle

import os
from glob import glob
import random

import pandas as pd

# %%
import pandas as pd
ft=pd.read_csv("names_tsfresh_union_features.csv")
col=list(ft["0"])
ft.head()
col.append("unnamed: 0")
mm_0=pd.read_csv("tsfresh_features_0hr_420.csv")
mm_col=list(mm_0.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_0.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_0.drop(columns=not_col,inplace=True)
mm_0 = mm_0.reindex(columns=sorted(mm_0.columns))
mm_0.head()
# Out:
#    heartrate__abs_energy  heartrate__absolute_sum_of_changes  \
# 0               363094.0                               484.0
# 1               304347.0                               302.0
# 2               412023.0                                 6.0
# 3               374194.0                               205.0
# 4               419873.0                               121.0
#
#    heartrate__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                          -0.030616
# 1                                           0.131312
# 2                                          -0.033406
# 3                                          -0.012027
# 4                                           0.020801
#
#    heartrate__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                          -0.028216
# 1                                           0.126889
# 2                                          -0.057964
# ...

# %%
mm_1=pd.read_csv("tsfresh_features_1hr_420.csv")
mm_col=list(mm_1.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_1.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_1.drop(columns=not_col,inplace=True) 
mm_1 = mm_1.reindex(columns=sorted(mm_1.columns))
mm_1.head()
# Out:
#    heartrate__abs_energy  heartrate__absolute_sum_of_changes  \
# 0               360803.0                               454.0
# 1               284649.0                               249.0
# 2               412023.0                                 6.0
# 3               360901.0                               229.0
# 4               413318.0                               110.0
#
#    heartrate__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                          -0.031509
# 1                                           0.153469
# 2                                          -0.026368
# 3                                           0.070769
# 4                                           0.033701
#
#    heartrate__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                          -0.038064
# 1                                           0.219764
# 2                                          -0.051226
# ...

# %%
mm_2=pd.read_csv("tsfresh_features_2hr_420.csv")
mm_col=list(mm_2.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_2.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_2.drop(columns=not_col,inplace=True)
mm_2 = mm_2.reindex(columns=sorted(mm_2.columns))
mm_2.head()
mm_3=pd.read_csv("tsfresh_features_3hr_420.csv")
mm_col=list(mm_3.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_3.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_3.drop(columns=not_col,inplace=True) 
mm_3 = mm_3.reindex(columns=sorted(mm_3.columns))
mm_3.head()
mm_4=pd.read_csv("tsfresh_features_4hr_420.csv")
mm_col=list(mm_4.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_4.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_4.drop(columns=not_col,inplace=True) 
mm_4 = mm_4.reindex(columns=sorted(mm_4.columns))
mm_4.head()
mm_5=pd.read_csv("tsfresh_features_5hr_420.csv")
mm_col=list(mm_5.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_5.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_5.drop(columns=not_col,inplace=True) 
mm_5 = mm_5.reindex(columns=sorted(mm_5.columns))
mm_5.head()
mm_6=pd.read_csv("tsfresh_features_6hr_420.csv")
mm_col=list(mm_6.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_6.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_6.drop(columns=not_col,inplace=True)
mm_6 = mm_6.reindex(columns=sorted(mm_6.columns))
mm_6.head()
mm_7=pd.read_csv("tsfresh_features_7hr_420.csv")
mm_col=list(mm_7.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_7.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_7.drop(columns=not_col,inplace=True) 
mm_7 = mm_7.reindex(columns=sorted(mm_7.columns))
mm_7.head()
# Out:
#    heartrate__abs_energy  heartrate__absolute_sum_of_changes  \
# 0               337965.0                               333.0
# 1               216410.0                               160.0
# 2               518528.0                                86.0
# 3               248455.0                               150.0
# 4               404911.0                               110.0
#
#    heartrate__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                           0.032640
# 1                                          -0.086272
# 2                                           0.123866
# 3                                          -0.081378
# 4                                           0.005429
#
#    heartrate__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                           0.018350
# 1                                          -0.217690
# 2                                          -0.098839
# ...

# %%
mm_8=pd.read_csv("tsfresh_features_8hr_420-Copy1.csv")
mm_col=list(mm_8.columns)
for i in range(0,len(mm_col)):
    mm_col[i]=mm_col[i].lower()
mm_8.columns = mm_col
not_col=[]
for val in mm_col:
    if val not in col:
        not_col.append(val)
mm_8.drop(columns=not_col,inplace=True) 
mm_8 = mm_8.reindex(columns=sorted(mm_8.columns))
mm_8.head()
# Out:
#    heartrate__abs_energy  heartrate__absolute_sum_of_changes  \
# 0               323985.0                               331.0
# 1               211935.0                               169.0
# 2               460407.0                               109.0
# 3               243345.0                               124.0
# 4               654564.0                                58.0
#
#    heartrate__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# 0                                           0.087067
# 1                                          -0.070601
# 2                                           0.025710
# 3                                          -0.112417
# 4                                          -0.023168
#
#    heartrate__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# 0                                           0.096156
# 1                                          -0.146734
# 2                                          -0.043004
# ...

# %%
print(len(mm_8))
# Out:
# 9050

# %%
Dict_age={}
Dict_gender={}
for j in range(1,6):
    val=pd.read_csv('train_test_val/val/'+str(j)+'hr.csv')
    test=pd.read_csv('train_test_val/test/'+str(j)+'hr.csv')
    train=pd.read_csv('train_test_val/train/'+str(j)+'hr.csv')
    
    for i in range(0,len(val)):
        ag=int(val["age"][i])
        gn=val["gender"][i]
        Dict_age[val["id"][i]]=ag
        if gn=="M":
            Dict_gender[val["id"][i]]=0
        else:
            Dict_gender[val["id"][i]]=1
            
    for i in range(0,len(test)):
        ag=int(test["age"][i])
        gn=test["gender"][i]
        Dict_age[test["id"][i]]=ag
        if gn=="M":
            Dict_gender[test["id"][i]]=0
        else:
            Dict_gender[test["id"][i]]=1
    
    for i in range(0,len(train)):
        ag=int(train["age"][i])
        gn=train["gender"][i]
        Dict_age[train["id"][i]]=ag

        if gn=="M":
            Dict_gender[train["id"][i]]=0
        else:
            Dict_gender[train["id"][i]]=1

# %%
import numpy as np
Dict_x_0 = {}
Dict_y_0={}
names=list(mm_0["unnamed: 0"])
x=mm_0.drop(columns=["unnamed: 0"])
for i in range(len(mm_0)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_0[ff]=pt
        Dict_y_0[ff]=hh
    except:
        pass
import numpy as np
Dict_x_1 = {}
Dict_y_1={}
names=list(mm_1["unnamed: 0"])
x=mm_1.drop(columns=["unnamed: 0"])
for i in range(len(mm_1)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_1[ff]=pt
        Dict_y_1[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_2 = {}
Dict_y_2={}
names=list(mm_2["unnamed: 0"])
x=mm_2.drop(columns=["unnamed: 0"])
for i in range(len(mm_2)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_2[ff]=pt
        Dict_y_2[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_3 = {}
Dict_y_3={}
names=list(mm_3["unnamed: 0"])
x=mm_3.drop(columns=["unnamed: 0"])
for i in range(len(mm_3)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_3[ff]=pt
        Dict_y_3[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_4 = {}
Dict_y_4={}
names=list(mm_4["unnamed: 0"])
x=mm_4.drop(columns=["unnamed: 0"])
for i in range(len(mm_4)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_4[ff]=pt
        Dict_y_4[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_5 = {}
Dict_y_5={}
names=list(mm_5["unnamed: 0"])
x=mm_5.drop(columns=["unnamed: 0"])
for i in range(len(mm_5)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_5[ff]=pt
        Dict_y_5[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_6 = {}
Dict_y_6={}
names=list(mm_6["unnamed: 0"])
x=mm_6.drop(columns=["unnamed: 0"])
for i in range(len(mm_6)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_6[ff]=pt
        Dict_y_6[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_7 = {}
Dict_y_7={}
names=list(mm_7["unnamed: 0"])
x=mm_7.drop(columns=["unnamed: 0"])
for i in range(len(mm_7)):
    try:
        ff=names[i]
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        ff = ff.replace('.csv',"")
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_7[ff]=pt
        Dict_y_7[ff]=hh
    except:
        pass

# %%
import numpy as np
Dict_x_8 = {}
Dict_y_8={}
names=list(mm_8["unnamed: 0"])
x=mm_8.drop(columns=["unnamed: 0"])
for i in range(len(mm_8)):
    ff=names[i]
    ff = ff.replace('.csv',"")
    try:
        
        pt=x.loc[[i], :]
        hh=-1
        if "_Abnormal_" in names[i]:
            hh=1
        elif "_Normal_" in names[i]:
            hh=0
        
        pt["age"]=Dict_age[ff]

        pt["gender"]=Dict_gender[ff]
        pt=np.array(pt)  
        Dict_x_8[ff]=pt
        Dict_y_8[ff]=hh
    except:
        pass

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
def cutoff_youdens_j(fpr,tpr,thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores,thresholds))
    return j_ordered[-1][1]
def plot_curve(H,EPO):
  import matplotlib.pyplot as plt
  N = np.arange(0, EPO)
  plt.style.use("ggplot")
  plt.figure(figsize=(16,9))
  plt.title("Training Loss and Accuracy ")
  plt.plot(N, H.history["accuracy"], label="train_acc")
  plt.plot(N, H.history["val_accuracy"], label="val_acc")
  plt.plot(N, H.history["loss"], label="train_loss")
  plt.plot(N, H.history["val_loss"], label="val_loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss/Accuracy")
  plt.legend(loc="best")
  plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    #print(feature_vector_valid.shape)
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    #print(predictions)
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
    acc=accuracy_score(valid_y, predictions)
    auc=roc_auc_score(valid_y, predictions)
    #auc=roc_auc_score(valid_y, classifier.predict_proba(feature_vector_valid))
    #pred_prob1 = classifier.predict_proba(feature_vector_valid)
    #auc = roc_auc_score(valid_y, pred_prob1[:,1])
    print("Classification report:")
    print(classification_report(valid_y, predictions))
    #print(predictions)
    return acc,auc

# %%
def cutoff_youdens_j(fpr,tpr,thresholds):
    j_scores = tpr-fpr
    j_ordered = sorted(zip(j_scores,thresholds))
    return j_ordered[-1][1]

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.preprocessing import StandardScaler

# %%
demo=pd.read_csv('demographics.csv')
demo['unittype'] =demo['unittype'].map({0:'CCU-CTICU',
 1:'CSICU',
 2:'CTICU',
 3:'Cardiac ICU',
 4:'MICU',
 5:'Med-Surg ICU',
 6:'Neuro ICU',
 7:'SICU'})

# %%
from imblearn.over_sampling import SMOTE
import pickle
import shap
from sklearn.ensemble import GradientBoostingClassifier
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from boruta import BorutaPy
import matplotlib.pyplot as plt
random.seed(3)
acc=[]
rec=[]
pre=[]
f1=[]
aucroc=[]
auprc=[]
spe=[]
sen=[]
PPV=[]
NPV=[]
you=[]
for kk in range(1):
    file1 = open("xgb_tsfresh.txt","w")
    for j in range(1,6):
        df=pd.DataFrame(columns=["Probabilities","Actual_labels","Cutoff"])
        
        
        train_x=[]
        train_y=[]
        val_x=[]
        val_y=[]
        test_x=[]
        test_y=[]
        
        train=pd.read_csv('train_test_val/train/'+str(j)+'hr.csv')
        
        
       
        for i in range(0,len(train)):
            hr=int(train["coh_hr"][i])
            if hr==0:
                train_id=train['id'][i]
                hh=Dict_x_0[train_id]
                train_x.append(hh[0])
                hh=Dict_y_0[train_id]
                train_y.append(hh)
            elif hr==1:
                train_id=train['id'][i]
                hh=Dict_x_1[train_id]
                train_x.append(hh[0])
                hh=Dict_y_1[train_id]
                train_y.append(hh)
            elif hr==2:
                train_id=train['id'][i]
                hh=Dict_x_2[train_id]
                train_x.append(hh[0])
                hh=Dict_y_2[train_id]
                train_y.append(hh)
            elif hr==3:
                train_id=train['id'][i]
                hh=Dict_x_3[train_id]
                train_x.append(hh[0])
                hh=Dict_y_3[train_id]
                train_y.append(hh)
            elif hr==4:
                train_id=train['id'][i]
                hh=Dict_x_4[train_id]
                train_x.append(hh[0])
                hh=Dict_y_4[train_id]
                train_y.append(hh)
            elif hr==5:
                train_id=train['id'][i]
                hh=Dict_x_5[train_id]
                train_x.append(hh[0])
                hh=Dict_y_5[train_id]
                train_y.append(hh)
            elif hr==6:
                train_id=train['id'][i]
                hh=Dict_x_6[train_id]
                train_x.append(hh[0])
                hh=Dict_y_6[train_id]
                train_y.append(hh)
            elif hr==7:
                train_id=train['id'][i]
                hh=Dict_x_7[train_id]
                train_x.append(hh[0])
                hh=Dict_y_7[train_id]
                train_y.append(hh)
            elif hr==8:
                train_id=train['id'][i]
                hh=Dict_x_8[train_id]
                train_x.append(hh[0])
                hh=Dict_y_8[train_id]
                train_y.append(hh)
                
        
        
        

        
        val=pd.read_csv('train_test_val/val/'+str(j)+'hr.csv')
        
        for i in range(0,len(val)):
            hr=int(val["coh_hr"][i])
            if hr==0:
                val_id=val['id'][i]
                hh=Dict_x_0[val_id]
                val_x.append(hh[0])
                hh=Dict_y_0[val_id]
                val_y.append(hh)
            elif hr==1:
                val_id=val['id'][i]
                hh=Dict_x_1[val_id]
                val_x.append(hh[0])
                hh=Dict_y_1[val_id]
                val_y.append(hh)
            elif hr==2:
                val_id=val['id'][i]
                hh=Dict_x_2[val_id]
                val_x.append(hh[0])
                hh=Dict_y_2[val_id]
                val_y.append(hh)
            elif hr==3:
                val_id=val['id'][i]
                hh=Dict_x_3[val_id]
                val_x.append(hh[0])
                hh=Dict_y_3[val_id]
                val_y.append(hh)
            elif hr==4:
                val_id=val['id'][i]
                hh=Dict_x_4[val_id]
                val_x.append(hh[0])
                hh=Dict_y_4[val_id]
                val_y.append(hh)
            elif hr==5:
                val_id=val['id'][i]
                hh=Dict_x_5[val_id]
                val_x.append(hh[0])
                hh=Dict_y_5[val_id]
                val_y.append(hh)
            elif hr==6:
                val_id=val['id'][i]
                hh=Dict_x_6[val_id]
                val_x.append(hh[0])
                hh=Dict_y_6[val_id]
                val_y.append(hh)
            elif hr==7:
                val_id=val['id'][i]
                hh=Dict_x_7[val_id]
                val_x.append(hh[0])
                hh=Dict_y_7[val_id]
                val_y.append(hh)
            elif hr==8:
                val_id=val['id'][i]
                hh=Dict_x_8[val_id]
                val_x.append(hh[0])
                hh=Dict_y_8[val_id]
                val_y.append(hh)

            
           
        test=pd.read_csv('train_test_val/test/'+str(j)+'hr.csv')
        
        for i in range(0,len(test)):
            hr=int(test["coh_hr"][i])
            if hr==0:
                test_id=test['id'][i]
                hh=Dict_x_0[test_id]
                test_x.append(hh[0])
                hh=Dict_y_0[test_id]
                test_y.append(hh)
            elif hr==1:
                test_id=test['id'][i]
                hh=Dict_x_1[test_id]
                test_x.append(hh[0])
                hh=Dict_y_1[test_id]
                test_y.append(hh)
            elif hr==2:
                test_id=test['id'][i]
                hh=Dict_x_2[test_id]
                test_x.append(hh[0])
                hh=Dict_y_2[test_id]
                test_y.append(hh)
            elif hr==3:
                test_id=test['id'][i]
                hh=Dict_x_3[test_id]
                test_x.append(hh[0])
                hh=Dict_y_3[test_id]
                test_y.append(hh)
            elif hr==4:
                test_id=test['id'][i]
                hh=Dict_x_4[test_id]
                test_x.append(hh[0])
                hh=Dict_y_4[test_id]
                test_y.append(hh)
            elif hr==5:
                test_id=test['id'][i]
                hh=Dict_x_5[test_id]
                test_x.append(hh[0])
                hh=Dict_y_5[test_id]
                test_y.append(hh)
            elif hr==6:
                test_id=test['id'][i]
                hh=Dict_x_6[test_id]
                test_x.append(hh[0])
                hh=Dict_y_6[test_id]
                test_y.append(hh)
            elif hr==7:
                test_id=test['id'][i]
                hh=Dict_x_7[test_id]
                test_x.append(hh[0])
                hh=Dict_y_7[test_id]
                test_y.append(hh)
            elif hr==8:
                test_id=test['id'][i]
                hh=Dict_x_8[test_id]
                test_x.append(hh[0])
                hh=Dict_y_8[test_id]
                test_y.append(hh)
            
            
            
        train_x=np.array(train_x)
        test_x=np.array(test_x)
        val_x=np.array(val_x)
        
        print(test_x.shape)
        print(train_x.shape)
        print(val_x.shape)
        from collections import Counter
        print(Counter(train_y))
        h=Counter(train_y)
        over = RandomUnderSampler()
        train_x,train_y=over.fit_resample(train_x,train_y)

    
        
        
        print(test_x.shape)
        print(train_x.shape)
        print(val_x.shape)
        print(Counter(train_y))
        
        
        
        
 
        
        
        
        
        scaler = StandardScaler()
        train_x = scaler.fit_transform(train_x)
        test_x = scaler.transform(test_x)
        val_x = scaler.transform(val_x)
        
        
        model = GradientBoostingClassifier(n_estimators=500, learning_rate=0.1,random_state=0)
        model.fit(train_x, train_y)
#         model=pickle.load(open('arushi_model.sav', 'rb'))
        y_test_prob = model.predict_proba(val_x)
        y_classes = np.round(y_test_prob[:,1])
        y_true = val_y
        fpr, tpr, thresholds =roc_curve(y_true, y_test_prob[:,1])
        youdens = cutoff_youdens_j(fpr, tpr, thresholds)
        y_test_prob = model.predict_proba(test_x)
        print(y_test_prob[:10])
        y_classes = (y_test_prob>youdens)*1
        y_classes=y_classes[:,1]
        y_true = test_y
        pickle.dump(model, open('xgb_2121_feature_selected_pro_fold/model'+str(j)+'.sav', 'wb'))
        df["Probabilities"]=y_test_prob[:,1]
        df["Actual_labels"]=y_true
        df["Cutoff"]=youdens
        temp_test=pd.read_csv('train_test_val/test/'+str(j)+'hr.csv')
        df["gender"]=temp_test["gender"]
        df["age"]=temp_test["age"]
        df["coh_hr"]=temp_test["coh_hr"]
        icutype=[]
        for ii in range(0,len(temp_test)):
            try:
                id_value=temp_test["id"][ii]
                #print(id_value)
                id_int=int(id_value.split("_")[0])
                ll=demo.loc[(demo["patientunitstayid"]== id_int)]
                #print(id_int)
                #print(ll)
                icutype.append(ll["unittype"].iloc[0])
            except:
                #print("hj")
                icutype.append("empty")
        df["ICUTYPE"]=icutype
        
        df.to_csv("xgb_2121_feature_selected_pro_fold/"+str(j)+".csv")
        #break
        from sklearn.metrics import precision_recall_curve
        pp,rr,th=precision_recall_curve(y_true,y_test_prob[:,1])
        auprc.append(auc(rr,pp))


        print("Accuracy: " + str(accuracy_score(y_true, y_classes)))
        print("Recall: " + str(recall_score(y_true, y_classes)))
        print("Precision: " + str(precision_score(y_true, y_classes)))
        print("F1 score: " + str(f1_score(y_true, y_classes)))
        print(y_true)
        print("ROC: " + str(roc_auc_score(y_true, y_test_prob[:,1])))
        acc.append(accuracy_score(y_true, y_classes))
        rec.append(recall_score(y_true, y_classes))
        pre.append(precision_score(y_true, y_classes))
        f1.append(f1_score(y_true, y_classes))

        aucroc.append(roc_auc_score(y_true, y_test_prob[:,1]))

        print(confusion_matrix(y_true, y_classes))
        file1.write("Split _____________________________ \n")
        file1.write("Accuracy   "+str(accuracy_score(y_true, y_classes))+"\n")
        file1.write("Recall:    "+str(recall_score(y_true, y_classes))+"\n")
        file1.write("Precision:   "+str(precision_score(y_true, y_classes))+"\n")
        file1.write("F1 score:   "+str(f1_score(y_true, y_classes))+"\n")
        file1.write("ROC:   "+str(roc_auc_score(y_true, y_test_prob[:,1]))+"\n")
        file1.write("auprc:   "+str(auc(rr,pp))+"\n")
        tn, fp, fn, tp = confusion_matrix(y_true, y_classes).ravel()
        specificity = tn / (tn+fp)
        file1.write("specificity:   "+str(specificity)+"\n")
        sensitivity = tp/(tp+fn)
        file1.write("sensitivity:   "+str(sensitivity)+"\n")
        spe.append(specificity)
        sen.append(sensitivity)
        ppv=tp/(tp+fp)
        npv=tn/(tn+fn)
        PPV.append(ppv)
        NPV.append(npv)
        you.append(youdens)
        
    file1.close()
# Out:
# (16983, 2122)
# (65457, 2122)
# (24851, 2122)
# Counter({1: 45433, 0: 20024})
# (16983, 2122)
# (40048, 2122)
# (24851, 2122)
# Counter({0: 20024, 1: 20024})

# %%
import statistics
print('Accuracy '+str(statistics.median(acc)))
print('Recall '+str(statistics.median(rec)))
print('Precision '+str(statistics.median(pre)))
print('F1 '+str(statistics.median(f1)))
print('AUC-ROC '+str(statistics.median(aucroc)))
print('Specivity '+str(statistics.median(spe)))
print('Sensitivity '+str(statistics.median(sen)))
print('PPV '+str(statistics.median(PPV)))
print('NPV '+str(statistics.median(NPV)))
print('AUprc '+str(statistics.median(auprc)))
print('Youden '+str(statistics.median(you)))
# Out:
# Accuracy 0.7844087340529932
# Recall 0.8008649420726869
# Precision 0.8820573326341549
# F1 0.839253751893157
# AUC-ROC 0.8614589753646738
# Specivity 0.7440029298663249
# Sensitivity 0.8008649420726869
# PPV 0.8820573326341549
# NPV 0.6328089887640449
# AUprc 0.9249300411237555
# Youden 0.6861526728654155

# %%
from statistics import stdev 
print('Accuracy '+str(stdev(acc)))
print('Recall '+str(stdev(rec)))
print('Precision '+str(stdev(pre)))
print('F1 '+str(stdev(f1)))
print('AUC-ROC '+str(stdev(aucroc)))
print('Specivity '+str(stdev(spe)))
print('Sensitivity '+str(stdev(sen)))
print('PPV '+str(stdev(PPV)))
print('NPV '+str(stdev(NPV)))
print('AUprc '+str(stdev(auprc)))
print('Youden '+str(stdev(you)))
# Out:
# Accuracy 0.010397119861667907
# Recall 0.03160523976124465
# Precision 0.02339624506895141
# F1 0.009750512111058788
# AUC-ROC 0.013909692662661453
# Specivity 0.04828031767305105
# Sensitivity 0.03160523976124465
# PPV 0.02339624506895141
# NPV 0.04090213176560309
# AUprc 0.012289928045880664
# Youden 0.035995631585285126
